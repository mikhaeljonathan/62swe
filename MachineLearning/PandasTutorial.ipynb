# %% [markdown]
# # Import Lib

# %%
import pandas as pd

# %% [markdown]
# # Creating Data Structures

# %%
# Series
s = pd.Series([1,2,3,4])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data = {'a': 10, 'b': 20, 'c': 30}
s = pd.Series(data)
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
# DataFrame
data = {'Name': ['John', 'Jane', 'Jim'], 'Age': [25, 30, 28]}
df = pd.DataFrame(data)
df
# Out:
#    Name  Age
# 0  John   25
# 1  Jane   30
# 2   Jim   28

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### This representation is called rich representation, it works in _repr_html_() function

# %%
# dir(df)

# %%
# help(pd.DataFrame)

# %%
# pd.DataFrame??

# %% [markdown]
# # Read CSV

# %%
df = pd.read_csv('employee.csv')
# df = pd.read_csv('employee.csv', index_col='name')
df
# Out:
#       name department    salary
# 0    alice         IT    3000.0
# 1      bob    finance    5000.0
# 2  charlie  marketing    1000.0
# 3    drake         hr    2000.0
# 4     elon        NaN  100000.0
# 5    frank         ob       NaN
# 6  gilbert         IT    4000.0

# %% [markdown]
# * NaN is specifically a numeric placeholder for missing data.
# * NA is a general concept for missing data in both numeric and non-numeric fields.
# * Null/None is a Python-specific object that represents missing values in object-type columns in Pandas, but it is automatically converted to NaN in numeric contexts.

# %% [markdown]
# # DataFrame Operation

# %%
df.shape
# Out:
# (7, 3)

# %%
# First 5 rows
df.head()
# Out:
#       name department    salary
# 0    alice         IT    3000.0
# 1      bob    finance    5000.0
# 2  charlie  marketing    1000.0
# 3    drake         hr    2000.0
# 4     elon        NaN  100000.0

# %%
# Last 5 rows
df.tail()
# Out:
#       name department    salary
# 2  charlie  marketing    1000.0
# 3    drake         hr    2000.0
# 4     elon        NaN  100000.0
# 5    frank         ob       NaN
# 6  gilbert         IT    4000.0

# %%
df.columns
# Out:
# Index(['name', 'department', 'salary'], dtype='object')

# %%
# Access specific column
print(df['name'])
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      drake
# 4       elon
# 5      frank
# 6    gilbert
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df = df.set_index('name')

# %%
# Access specific row
df.loc['bob']
# Out:
# department    finance
# salary         5000.0
# Name: bob, dtype: object

# %%
df.loc[['bob', 'elon']]
# Out:
#      department    salary
# name
# bob     finance    5000.0
# elon        NaN  100000.0

# %%
df.loc['alice', 'department']
# Out:
# 'IT'

# %%
df.iloc[[0, 2]]
# Out:
#         department  salary
# name
# alice           IT  3000.0
# charlie  marketing  1000.0

# %%
df.iloc[:, 1]
# Out:
# name
# alice        3000.0
# bob          5000.0
# charlie      1000.0
# drake        2000.0
# elon       100000.0
# frank           NaN
# gilbert      4000.0
# Name: salary, dtype: float64

# %%
df.iloc[-3:]
# Out:
#         department    salary
# name
# elon           NaN  100000.0
# frank           ob       NaN
# gilbert         IT    4000.0

# %%
# summary of numeric data (by default filtered by number datatype, int or float)
df.describe()
# Out:
#               salary
# count       6.000000
# mean    19166.666667
# std     39625.328600
# min      1000.000000
# 25%      2250.000000
# 50%      3500.000000
# 75%      4750.000000
# max    100000.000000

# %%
df['salary']
# Out:
# name
# alice        3000.0
# bob          5000.0
# charlie      1000.0
# drake        2000.0
# elon       100000.0
# frank           NaN
# gilbert      4000.0
# Name: salary, dtype: float64

# %%
df['salary'].mean()
# Out:
# 19166.666666666668

# %%
df['salary'].agg([sum,min,max,'mean'])
# Out:
# <ipython-input-69-53664d3808cd>:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df['salary'].agg([sum,min,max,'mean'])
# <ipython-input-69-53664d3808cd>:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df['salary'].agg([sum,min,max,'mean'])
# <ipython-input-69-53664d3808cd>:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df['salary'].agg([sum,min,max,'mean'])
# sum     115000.000000
# min       1000.000000
# max     100000.000000
# mean     19166.666667
# Name: salary, dtype: float64

# %%
df['department'].value_counts()
# Out:
# department
# IT           2
# finance      1
# marketing    1
# hr           1
# ob           1
# Name: count, dtype: int64

# %%
df['department'].unique()
# Out:
# array(['IT', 'finance', 'marketing', 'hr', nan, 'ob'], dtype=object)

# %% [markdown]
# # Filtering and Selecting data

# %%
df[df['salary'] > 2000]
# Out:
#         department    salary
# name
# alice           IT    3000.0
# bob        finance    5000.0
# elon           NaN  100000.0
# gilbert         IT    4000.0

# %%
df[df['department'] == 'IT']
# Out:
#         department  salary
# name
# alice           IT  3000.0
# gilbert         IT  4000.0

# %%
df[(df['department'] == 'IT') & (df['salary'] > 3500)]
# Out:
#         department  salary
# name
# gilbert         IT  4000.0

# %%
df[(df['department'] == 'IT') | (df['salary'] > 3500)]
# Out:
#         department    salary
# name
# alice           IT    3000.0
# bob        finance    5000.0
# elon           NaN  100000.0
# gilbert         IT    4000.0

# %%
df['department'].isin(['IT', 'marketing'])
# Out:
# name
# alice       True
# bob        False
# charlie     True
# drake      False
# elon       False
# frank      False
# gilbert     True
# Name: department, dtype: bool

# %%
df.loc[df['department'].isin(['IT', 'marketing'])]
# Out:
#         department  salary
# name
# alice           IT  3000.0
# charlie  marketing  1000.0
# gilbert         IT  4000.0

# %%
df[['salary','department']]
# Out:
#            salary department
# name
# alice      3000.0         IT
# bob        5000.0    finance
# charlie    1000.0  marketing
# drake      2000.0         hr
# elon     100000.0        NaN
# frank         NaN         ob
# gilbert    4000.0         IT

# %%
type(df[['salary']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Adding and Dropping Columns

# %%
df['bonus'] = df['salary'] * 0.1
df
# Out:
#         department    salary    bonus
# name
# alice           IT    3000.0    300.0
# bob        finance    5000.0    500.0
# charlie  marketing    1000.0    100.0
# drake           hr    2000.0    200.0
# elon           NaN  100000.0  10000.0
# frank           ob       NaN      NaN
# gilbert         IT    4000.0    400.0

# %%
df = df.drop('bonus', axis=1)
df
# Out:
#         department    salary
# name
# alice           IT    3000.0
# bob        finance    5000.0
# charlie  marketing    1000.0
# drake           hr    2000.0
# elon           NaN  100000.0
# frank           ob       NaN
# gilbert         IT    4000.0

# %% [markdown]
# # Handling missing data

# %%
df['salary'].fillna(0)
# Out:
# name
# alice        3000.0
# bob          5000.0
# charlie      1000.0
# drake        2000.0
# elon       100000.0
# frank           0.0
# gilbert      4000.0
# Name: salary, dtype: float64

# %%
df.dropna()
# Out:
#         department  salary
# name
# alice           IT  3000.0
# bob        finance  5000.0
# charlie  marketing  1000.0
# drake           hr  2000.0
# gilbert         IT  4000.0

# %%
df.isnull().sum()
# Out:
# department    1
# salary        1
# dtype: int64

# %% [markdown]
# # GroupBy

# %%
df_groupby = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
df_groupby
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df_groupby.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
# Hierarchical index
arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          ['Captive', 'Wild', 'Captive', 'Wild']]
index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
df_groupby = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
                  index=index)
df_groupby
# Out:
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0

# %%
df_groupby.groupby(level=0).mean()
# Out:
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0

# %%
df_groupby.groupby(level="Type").mean()
# Out:
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0

# %% [markdown]
# # Merge, Join

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        5  foo        5
# 5  foo        5  foo        8

# %%
df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})
df1
# Out:
#      a  b
# 0  foo  1
# 1  bar  2

# %%
df2
# Out:
#      a  c
# 0  foo  3
# 1  baz  4

# %%
df1.merge(df2, how='inner', on='a')
# Out:
#      a  b  c
# 0  foo  1  3

# %%
df1.merge(df2, how='left', on='a')
# Out:
#      a  b    c
# 0  foo  1  3.0
# 1  bar  2  NaN

# %% [markdown]
# # Sort data

# %%
df_sorted = df.sort_values(by='salary')
df_sorted
# Out:
#         department    salary
# name
# charlie  marketing    1000.0
# drake           hr    2000.0
# alice           IT    3000.0
# gilbert         IT    4000.0
# bob        finance    5000.0
# elon           NaN  100000.0
# frank           ob       NaN

# %%
df_sorted = df.sort_values(by=['department', 'salary'])
df_sorted
# Out:
#         department    salary
# name
# alice           IT    3000.0
# gilbert         IT    4000.0
# bob        finance    5000.0
# drake           hr    2000.0
# charlie  marketing    1000.0
# frank           ob       NaN
# elon           NaN  100000.0

# %%
df_sorted.rename(columns={'salary': 'monthly_salary'})
# Out:
#         department  monthly_salary
# name
# alice           IT          3000.0
# gilbert         IT          4000.0
# bob        finance          5000.0
# drake           hr          2000.0
# charlie  marketing          1000.0
# frank           ob             NaN
# elon           NaN        100000.0

# %% [markdown]
# # Export

# %%
df_sorted = df.sort_values(by='salary')
df_sorted.to_csv('output.csv')
